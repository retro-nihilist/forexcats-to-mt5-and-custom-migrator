# %%
# Читаем файл и пересохраняем в UTF-8
with open('code-summary.txt', 'r', encoding='utf-8', errors='ignore') as f:
    content = f.read()

with open('code-summary-utf8.txt', 'w', encoding='utf-8') as f:
    f.write(content)

print("Файл успешно пересохранен в UTF-8!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Читаем файл и пересохраняем в UTF-8
# ----> 2 with open('code-summary.txt', 'r', encoding='utf-8', errors='ignore') as f:
#       3     content = f.read()
#       5 with open('code-summary-utf8.txt', 'w', encoding='utf-8') as f:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'code-summary.txt'

# %%
# !npx repomix --style plain \
--include "**/*.mq5,**/*.py,**/*.cpp,**/*.mqh,**/*.ipynb" \
--ignore "files/**,migration_errors/**,own_platform/**,GitHub_through_Python/**,Migrating-ForexCat-platform-to-MetaTrader5/**" \
--output Migrating-ForexCat-platform-to-MetaTrader5.txt
# Out:
# 📦 Repomix v1.18.0
#
# No custom config found at repomix.config.ts, repomix.config.mts, repomix.config.cts, repomix.config.js, repomix.config.mjs, repomix.config.cjs, repomix.config.json5, repomix.config.jsonc, repomix.config.json or global config at C:\Users\nigilist\AppData\Local\Repomix\repomix.config.ts, C:\Users\nigilist\AppData\Local\Repomix\repomix.config.mts, C:\Users\nigilist\AppData\Local\Repomix\repomix.config.cts, C:\Users\nigilist\AppData\Local\Repomix\repomix.config.js, C:\Users\nigilist\AppData\Local\Repomix\repomix.config.mjs, C:\Users\nigilist\AppData\Local\Repomix\repomix.config.cjs, C:\Users\nigilist\AppData\Local\Repomix\repomix.config.json5, C:\Users\nigilist\AppData\Local\Repomix\repomix.config.jsonc, C:\Users\nigilist\AppData\Local\Repomix\repomix.config.json.
# You can add a config file for additional settings. Please check https://github.com/yamadashy/repomix for more information.
#
# ⠋ Initializing...
#
#
# ⠙ Searching for files...
#
#
# ...
